# %%
import sim
# Out:
# Fox Setup
# Processed 1005 tickers in 5.977s seconds
# Top 10 Crypto (Static) : Fox simulate start
# 2017-08-01 00:00:00 : 9801.000
# 2017-11-09 00:00:00 : 15621.624
# 2018-02-17 00:00:00 : 45893.070
# 2018-03-04 00:00:00 : 40403.849
# Fox simulate completed
# NVDA : Fox simulate start
# 2017-08-01 00:00:00 : 9801.000
# 2017-11-09 00:00:00 : 12244.356
# 2018-02-17 00:00:00 : 14631.031
# 2018-03-04 00:00:00 : 13995.483
# Fox simulate completed
# Short VXX : Fox simulate start
# 2017-08-01 00:00:00 : 10001.000
# 2017-11-09 00:00:00 : 12308.462
# 2018-02-17 00:00:00 : 10533.752
# 2018-03-04 00:00:00 : 9563.261
# Fox simulate completed
# SP500 (VOO) : Fox simulate start
# 2017-08-01 00:00:00 : 9801.000
# 2017-11-09 00:00:00 : 10286.159
# 2018-02-17 00:00:00 : 10936.037
# 2018-03-04 00:00:00 : 10750.832
# Fox simulate completed
# Top 10 Crypto (Weekly re.) : Fox simulate start
# 2017-08-01 00:00:00 : 10000.000
# 2017-11-09 00:00:00 : 16464.156
# 2018-02-17 00:00:00 : 62328.997
# ...

# %%
import matplotlib.pyplot as plt

# %%
sim.returns.iloc[:,[0,7]].plot()
plt.show()

# %%
sim.returns
# Out:
#             Top 10 Crypto (Static)      NVDA  Short VXX  SP500 (VOO)  \
# time
# 2017-08-01                1.000000  1.000000   1.000000     1.000000
# 2017-08-02                1.005613  0.999392   0.992762     1.000572
# 2017-08-03                1.047528  1.012098   0.980094     0.998811
# 2017-08-04                1.080943  1.016535   0.987333     1.000484
# 2017-08-05                1.157420  1.014317   0.983714     0.999648
# 2017-08-06                1.155564  1.032160   0.991857     1.001299
# 2017-08-07                1.223136  1.047784   0.996381     1.002113
# 2017-08-08                1.289015  1.035321   0.967427     1.000132
# 2017-08-09                1.266187  1.046325   0.941188     0.999559
# 2017-08-10                1.281133  1.001520   0.797326     0.985824
# 2017-08-11                1.328174  0.948142   0.763848     0.987145
# 2017-08-12                1.327549  0.985956   0.780587     0.986485
# ...

# %%
sim.returns['Low Cap Alpha vs Top 10 (Weekly Re.)'] = sim.returns['Crypto 150-500 (Weekly re.)']-sim.returns['Top 10 Crypto (Weekly re.)']

# %%
sim.returns.iloc[:,[4,6,8]].plot()
plt.show()
